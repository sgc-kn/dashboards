# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('produkt_klima_tag_19590701_20231231_02712.txt', delimiter=';')
df
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4    RSK  RSKF      SDK  \
# 0             2712    19590701     5  11.8   4.3  -999 -999.0  -999 -999.000
# 1             2712    19590702     5   8.8   3.7  -999 -999.0  -999 -999.000
# 2             2712    19590703     5  14.2   2.3  -999 -999.0  -999 -999.000
# 3             2712    19590704     5   5.2   1.8  -999 -999.0  -999 -999.000
# 4             2712    19590705     5   4.4   1.0  -999 -999.0  -999 -999.000
# ...            ...         ...   ...   ...   ...   ...    ...   ...      ...
# 23555         2712    20231227     3   3.7   1.0     3    0.0     4    0.617
# 23556         2712    20231228     3   3.3   1.1     3    0.0     6    0.000
# 23557         2712    20231229     3   9.0   2.2     3    0.2     6    0.467
# 23558         2712    20231230     3   7.8   2.1     3    0.0     0    7.133
# 23559         2712    20231231     3  12.6   2.4     3    2.1     6    0.917
#
# ...

# %%
datum_keine_daten = df.loc[df[' TXK'] == -999.00, 'MESS_DATUM'].tolist()
daten_vollst = df.loc[~(df == -999.00).any(axis=1)]

# %%
df.loc[~(df == -999.00).any(axis=1)]
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4   RSK  RSKF    SDK  \
# 4872          2712    19721101     5   1.0   0.2     5   0.2     1  2.300
# 4873          2712    19721102     5   2.1   0.1     5   0.3     1  0.000
# 4874          2712    19721103     5   2.6   0.3     5   0.2     1  0.000
# 4875          2712    19721104     5   1.8   0.2     5   0.2     1  0.000
# 4876          2712    19721105     5   2.0   0.2     5   0.1     1  0.100
# ...            ...         ...   ...   ...   ...   ...   ...   ...    ...
# 23555         2712    20231227     3   3.7   1.0     3   0.0     4  0.617
# 23556         2712    20231228     3   3.3   1.1     3   0.0     6  0.000
# 23557         2712    20231229     3   9.0   2.2     3   0.2     6  0.467
# 23558         2712    20231230     3   7.8   2.1     3   0.0     0  7.133
# 23559         2712    20231231     3  12.6   2.4     3   2.1     6  0.917
#
#        SHK_TAG    NM   VPM      PM   TMK    UPM   TXK   TNK   TGK  eor
# ...

# %%
daten_vollst
# Out:
#        STATIONS_ID  MESS_DATUM  QN_3    FX    FM  QN_4   RSK  RSKF    SDK  \
# 4872          2712    19721101     5   1.0   0.2     5   0.2     1  2.300
# 4873          2712    19721102     5   2.1   0.1     5   0.3     1  0.000
# 4874          2712    19721103     5   2.6   0.3     5   0.2     1  0.000
# 4875          2712    19721104     5   1.8   0.2     5   0.2     1  0.000
# 4876          2712    19721105     5   2.0   0.2     5   0.1     1  0.100
# ...            ...         ...   ...   ...   ...   ...   ...   ...    ...
# 23555         2712    20231227     3   3.7   1.0     3   0.0     4  0.617
# 23556         2712    20231228     3   3.3   1.1     3   0.0     6  0.000
# 23557         2712    20231229     3   9.0   2.2     3   0.2     6  0.467
# 23558         2712    20231230     3   7.8   2.1     3   0.0     0  7.133
# 23559         2712    20231231     3  12.6   2.4     3   2.1     6  0.917
#
#        SHK_TAG    NM   VPM      PM   TMK    UPM   TXK   TNK   TGK  eor
# ...

# %%
datum_keine_daten
# Out:
# [19590701,
#  19590702,
#  19590703,
#  19590704,
#  19590705,
#  19590706,
#  19590707,
#  19590708,
#  19590709,
#  19590710,
#  19590711,
#  19590712,
#  19590713,
#  19590714,
#  19590715,
#  19590716,
#  19590717,
#  19590718,
#  19590719,
#  19590720,
#  19590721,
#  19590722,
#  19590723,
#  19590724,
#  19590725,
#  19590726,
#  19590727,
#  19590728,
#  19590729,
#  19590730,
#  19590731,
#  19590801,
#  19590802,
#  19590803,
#  19590804,
#  19590805,
#  19590806,
#  19590807,
#  19590808,
#  19590809,
#  19590810,
#  19590811,
#  19590812,
#  19590813,
#  19590814,
#  19590815,
#  19590816,
#  19590817,
#  19590818,
#  19590819,
#  19590820,
#  19590821,
#  19590822,
#  19590823,
#  19590824,
#  19590825,
#  19590826,
#  19590827,
#  19590828,
#  19590829,
#  19590830,
#  19590831,
#  19590901,
#  19590902,
#  19590903,
#  19590904,
#  19590905,
#  19590906,
#  19590907,
#  19590908,
#  19590909,
#  19590910,
#  19590911,
#  19590912,
#  19590913,
#  19590914,
# ...

# %%
tag_max_lufttemp = df.loc[:,' TXK']#Tagesmaximum der Lufttemperatur in 2m Höhe

# %%
tag_max_lufttemp.value_counts()
# Out:
#  TXK
# -999.0    4872
#  17.3       86
#  22.2       85
#  21.7       82
#  9.5        81
#           ...
#  36.4        1
#  36.5        1
#  36.6        1
#  36.7        1
#  36.9        1
# Name: count, Length: 459, dtype: int64

# %%
datum = data_Markstätte['dateobserved'].to_list()
niederschlag = data_Markstätte['precipitation'].to_list()

# %%
fig, ax = plt.subplots()
ax.scatter(datum[0:1000], niederschlag[0:1000])

# %% [markdown]
# ### DWD ###

# %%
data_dwd
# Out:
#     Jahr  Temperatur_Celsius_Mittel_Tagesdurchschnitt  \
# 0   1973                                         8.86
# 1   1974                                         9.55
# 2   1975                                         9.40
# 3   1976                                         9.41
# 4   1977                                         9.57
# 5   1978                                         8.53
# 6   1979                                         9.07
# 7   1980                                         8.38
# 8   1981                                         9.16
# 9   1982                                         9.60
# 10  1983                                         9.71
# 11  1984                                         8.80
# 12  1985                                         8.63
# 13  1986                                         8.95
# 14  1987                                         8.81
# 15  1988                                         9.95
# ...

# %%
df_wetter = pd.read_csv('wetter_jahreswerte_02712_19730101_20151231_hist/produkt_wetter_jahr_19730101_20151231_02712.txt', delimiter=';')

# %%
df_wetter
df_wetter['JAHR'] = df_wetter['MESS_DATUM_BEGINN'].astype(str).str[:4]

# %%
df_wetter
# Out:
#     STATIONS_ID  MESS_DATUM_BEGINN  MESS_DATUM_ENDE  QN_4  JA_STURM_6  \
# 0          2712           19730101         19731231     5           4
# 1          2712           19740101         19741231     5          12
# 2          2712           19750101         19751231     5           1
# 3          2712           19760101         19761231     5           8
# 4          2712           19770101         19771231     5           8
# 5          2712           19780101         19781231     5           3
# 6          2712           19790101         19791231     5           7
# 7          2712           19800101         19801231     5           5
# 8          2712           19810101         19811231    10           6
# 9          2712           19820101         19821231    10           4
# 10         2712           19830101         19831231    10           6
# 11         2712           19840101         19841231    10           6
# ...

# %%
fig, ax = plt.subplots(figsize= (20,5))

ax.scatter(df_wetter['JAHR'], df_wetter['JA_HAGEL'])
ax.set_title('Anzahl der Tage mit Hagel im Jahr')
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize= (20,5))

ax.scatter(df_wetter['JAHR'], df_wetter['JA_NEBEL'])
ax.set_title('Anzahl der Tage mit Nebel im Jahr')
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize= (20,5))

ax.scatter(df_wetter['JAHR'], df_wetter['JA_GLATTEIS'])
ax.set_title('Anzahl der Tage mit Glatteis im Jahr')
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize= (20,5))

ax.scatter(df_wetter['JAHR'], df_wetter['JA_GEWITTER'])
ax.set_title('Anzahl der Tage mit Gewitter im Jahr')
ax.grid()
plt.show()
